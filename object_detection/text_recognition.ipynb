# %% [markdown]
# # Text Recognition

# %%
from google.colab import drive
from os.path import join 

ROOT = "/content/gdrive/"
drive.mount(ROOT)
# Out:
# Mounted at /content/gdrive/

# %%
# !wget http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtestnoimgs_06-Nov-2007.tar
# Out:
# --2021-11-25 13:05:42--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtestnoimgs_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12492800 (12M) [application/x-tar]
# Saving to: ‘VOCtestnoimgs_06-Nov-2007.tar’
#
# VOCtestnoimgs_06-No 100%[===================>]  11.91M  10.5MB/s    in 1.1s
#
# 2021-11-25 13:05:43 (10.5 MB/s) - ‘VOCtestnoimgs_06-Nov-2007.tar’ saved [12492800/12492800]

# %%
# !tar -xvf VOCtestnoimgs_06-Nov-2007.tar
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# VOCdevkit/VOC2007/Annotations/000784.xml
# VOCdevkit/VOC2007/Annotations/000785.xml
# VOCdevkit/VOC2007/Annotations/000788.xml
# VOCdevkit/VOC2007/Annotations/000789.xml
# VOCdevkit/VOC2007/Annotations/000790.xml
# VOCdevkit/VOC2007/Annotations/000792.xml
# VOCdevkit/VOC2007/Annotations/000795.xml
# VOCdevkit/VOC2007/Annotations/000798.xml
# VOCdevkit/VOC2007/Annotations/000801.xml
# VOCdevkit/VOC2007/Annotations/000803.xml
# VOCdevkit/VOC2007/Annotations/000807.xml
# VOCdevkit/VOC2007/Annotations/000809.xml
# VOCdevkit/VOC2007/Annotations/000811.xml
# VOCdevkit/VOC2007/Annotations/000813.xml
# VOCdevkit/VOC2007/Annotations/000817.xml
# VOCdevkit/VOC2007/Annotations/000819.xml
# VOCdevkit/VOC2007/Annotations/000821.xml
# VOCdevkit/VOC2007/Annotations/000824.xml
# VOCdevkit/VOC2007/Annotations/000825.xml
# VOCdevkit/VOC2007/Annotations/000833.xml
# VOCdevkit/VOC2007/Annotations/000835.xml
# VOCdevkit/VOC2007/Annotations/000836.xml
# ...

# %%
# !ls
# Out:
# gdrive	sample_data  VOCdevkit	VOCtestnoimgs_06-Nov-2007.tar

# %%
# !cd ..
