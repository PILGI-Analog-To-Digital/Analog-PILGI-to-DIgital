# %%
from google.colab import drive
drive.mount("/content/gdrive/")
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
# %cd /content/gdrive/Shareddrives/machine_learning_in_practice/Analog-PILGI-to-DIgital/object_detection/refernce data
# !git clone https://github.com/parksunwoo/ocr_kor.git
# Out:
# /content/gdrive/Shareddrives/machine_learning_in_practice/Analog-PILGI-to-DIgital/object_detection/refernce data
# Cloning into 'ocr_kor'...
# remote: Enumerating objects: 522, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 522 (delta 19), reused 60 (delta 18), pack-reused 460
# Receiving objects: 100% (522/522), 215.91 MiB | 14.05 MiB/s, done.
# Resolving deltas: 100% (54/54), done.
# Checking out files: 100% (270/270), done.

# %%
# !git status
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-6056e448d387> in <module>()
# ----> 1 get_ipython().system('git status')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     100       kwargs.update({'also_return_output': True})
#     101
# --> 102     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     103
#     104     if pip_warn:
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     445   # stack.
#     446   result = _run_command(
# --> 447       shell.var_expand(cmd, depth=2), clear_streamed_output=False)
#     448   shell.user_ns['_exit_code'] = result.returncode
#     449   if -result.returncode in _INTERRUPTED_SIGNALS:
#
# ...

# %%
# !git add /content/gdrive/Shareddrives/machine_learning_in_practice/Analog-PILGI-to-DIgital/object_detection
# Out:
# ...
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> object_detection/ocr_kor
# hint:
# hint: If you added this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached object_detection/ocr_kor
# hint:
# hint: See "git help submodule" for more information.
# ...

# %%
# !git commit -m"[ADD] - reference repository"

# %%
# !git reset HEAD
# Out:
# Unstaged changes after reset:
# M	GAN/Parsing.ipynb
# M	GAN/WGAN_DIV.ipynb
# M	GAN/model/SelfAttention_Wasserstein/discriminator.pth
# M	GAN/model/SelfAttention_Wasserstein/generator.pth
# M	GAN/myDataDataset.ipynb
# M	GAN/selfAttentionGAN.ipynb
# M	GAN/transferLearning.ipynb
# D	object_detection/20211119 실전기계학습 실습 코드 (1).ipynb
# D	object_detection/20211119 실전기계학습 실습 코드 (1).ipynb
# D	object_detection/ctpn_model.py
# D	object_detection/ctpn_utils.py
# D	object_detection/dataset.py
# D	object_detection/error_imgs.txt
# D	object_detection/github_util.ipynb의 사본의 사본
# D	object_detection/object_detection.ipynb
# D	object_detection/test_data/1001.png
# D	object_detection/test_data_generating_file/1.hwp
# D	object_detection/test_data_generating_file/data_crawer.ipynb
# D	object_detection/test_data_generating_file/index.html?com=downloads
# D	object_detection/test_data_generator.ipynb
# D	object_detection/text_detector.ipynb
# D	object_detection/text_recognition.ipynb
