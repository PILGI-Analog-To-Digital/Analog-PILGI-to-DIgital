# %%
from google.colab import drive
from os.path import join 

ROOT = "/content/gdrive/"
drive.mount(ROOT)

# %cd /content/gdrive/Shareddrives/machine_learning_in_practice/Analog-PILGI-to-DIgital/object_detection/test_data_generating_file

# %%
# !wget --no-check-certificate -O- https://rrc.cvc.uab.es/?com=downloads&action=download&ch=8&f=aHR0cHM6Ly9kYXRhc2V0cy5jdmMudWFiLmVzL3JyYy9jaDhfdHJhaW5pbmdfaW1hZ2VzXzEuemlw
# Out:
# --2021-11-24 16:23:50--  https://rrc.cvc.uab.es/?com=downloads
# Resolving rrc.cvc.uab.es (rrc.cvc.uab.es)... 158.109.8.55
# Connecting to rrc.cvc.uab.es (rrc.cvc.uab.es)|158.109.8.55|:443... connected.
# WARNING: cannot verify rrc.cvc.uab.es's certificate, issued by ‘CN=GEANT OV RSA CA 4,O=GEANT Vereniging,C=NL’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘STDOUT’
#
# -                       [<=>                 ]       0  --.-KB/s               <!DOCTYPE HTML>
# <html>
#     <head>
#         <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
#         <title>Downloads - Robust Reading Competition</title>
#         <meta name='viewport' content='width=device-width, initial-scale=1'>
#
# <script type='text/javascript' src='js/jquery/jquery-1.11.1.min.js?ts=20210505' type='text/javascript'></script>
# ...

# %%
# !wget https://rrc.cvc.uab.es/?com=downloads&action=download&ch=8&f=aHR0cHM6Ly9kYXRhc2V0cy5jdmMudWFiLmVzL3JyYy9jaDhfdHJhaW5pbmdfaW1hZ2VzXzEuemlw
# Out:
# --2021-11-24 16:36:51--  https://rrc.cvc.uab.es/?com=downloads
# Resolving rrc.cvc.uab.es (rrc.cvc.uab.es)... 158.109.8.55
# Connecting to rrc.cvc.uab.es (rrc.cvc.uab.es)|158.109.8.55|:443... connected.
# ERROR: cannot verify rrc.cvc.uab.es's certificate, issued by ‘CN=GEANT OV RSA CA 4,O=GEANT Vereniging,C=NL’:
#   Unable to locally verify the issuer's authority.
# To connect to rrc.cvc.uab.es insecurely, use `--no-check-certificate'.
