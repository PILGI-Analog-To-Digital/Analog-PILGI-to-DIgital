# %% [markdown]
# # test CTPN
# check point를 이용해서, <br>
# 1_input image -> 2_extracted txt<br>
# txt img와 without txt 이미지를 생성 <br>

# %%
# !pip install import-ipynb
import import_ipynb
import os
import numpy as np
import cv2

input_data = './1_input_img/1001.png'
output_txt_dir = './2_extracted_txt_img/txt_img/'
output_no_txt_dir = './2_extracted_txt_img/without_txt_img/'

a = cv2.imread(input_data)
cv2.imshow('image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ...
# None

# %% [markdown]
# # test CRNN

# %%
import import_ipynb

# %% [markdown]
# # Test RCNN
