# %% [markdown]
# # github 설정

# %% [markdown]
# 1. 안 되면 token 등록해보기

# %%
from google.colab import drive
from os.path import join  

ROOT = "/content/gdrive/"
drive.mount(ROOT)

ORGANIZATION_NAME = "PILGI-Analog-To-Digital"
GIT_REPOSITORY = "Analog-PILGI-to-DIgital" 
GIT_TOKEN = ""  

# !git config --global user.email # 이메일 입력 ex) !git config --global user.email qhrqufdlek@naver.com
# !git config --global user.name  #깃헙 아이디 입력 ex) !git config --global user.name luckydipper

MY_GOOGLE_DRIVE_PATH = "/content/gdrive/Shareddrives/machine_learning_in_practice/Analog-PILGI-to-DIgital"

PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)
print("PROJECT_PATH: ", PROJECT_PATH)   

GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + ORGANIZATION_NAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)

# %cd "{PROJECT_PATH}"
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# PROJECT_PATH:  /content/gdrive/Shareddrives/machine_learning_in_practice/Analog-PILGI-to-DIgital
# GIT_PATH:  https://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@github.com/PILGI-Analog-To-Digital/Analog-PILGI-to-DIgital.git
# /content/gdrive/Shareddrives/machine_learning_in_practice/Analog-PILGI-to-DIgital

# %% [markdown]
# 2. 만약 commit 된다면

# %%
from google.colab import drive
from os.path import join  

ROOT = "/content/gdrive/"
drive.mount(ROOT)
MY_GOOGLE_DRIVE_PATH = "/content/gdrive/Shareddrives/machine_learning_in_practice/Analog-PILGI-to-DIgital"
# %cd "{MY_GOOGLE_DRIVE_PATH}"
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# /content/gdrive/Shareddrives/machine_learning_in_practice/Analog-PILGI-to-DIgital

# %%
# !git config --global user.email qhrqufdlek@naver.com # 이메일 입력
# !git config --global user.name luckydipper #깃헙 아이디 입력

# %%
# !git add -A

# %%
# !git commit -m"[ADD] - colab initial file"

# %%
# !git push
# Out:
# Counting objects: 6, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 2.97 KiB | 760.00 KiB/s, done.
# Total 6 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/PILGI-Analog-To-Digital/Analog-PILGI-to-DIgital.git
#    bd7dc2d..0b10e0f  main -> main

# %% [markdown]
# # GPU 사용법

# %% [markdown]
# # Transfer learning

# %%
% cd /content/gdrive/Shareddrives/machine_learning_in_practice
#%cd /content/
# Out:
# /content/gdrive/Shareddrives/machine_learning_in_practice

# %% [markdown]
# # Model Saving

# %%
# !git clone "{GIT_PATH}"
# Out:
# Cloning into 'Analog-PILGI-to-DIgital'...
# remote: Repository not found.
# fatal: repository 'https://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@github.com/Analog-PILGI-to-DIgital/Analog-PILGI-to-DIgital.git/' not found
